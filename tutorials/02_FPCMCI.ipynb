# %% [markdown]
# # FPCMCI
# This tutorial aims to explain how to perform a causal analysis by using the FPCMCI.
# We will cover the following parts:
# * 1 - Filtered - PCMCI
# * 2 - Example
# * 3 - FPCMCI vs PCMCI
#
# <br>
# First of all, we need to import the following packages:

# %%
from tigramite.independence_tests.gpdc import GPDC
from fpcmci.CPrinter import CPLevel
from fpcmci.FPCMCI import FPCMCI
from fpcmci.preprocessing.data import Data
from fpcmci.preprocessing.subsampling_methods.Static import Static
from fpcmci.preprocessing.subsampling_methods.SubsamplingMethod import SubsamplingMethod
from fpcmci.preprocessing.subsampling_methods.WSDynamic import WSDynamic
from fpcmci.preprocessing.subsampling_methods.WSFFTStatic import WSFFTStatic
from fpcmci.preprocessing.subsampling_methods.WSStatic import WSStatic
from fpcmci.selection_methods.TE import TE, TEestimator
from fpcmci.basics.constants import LabelType
import numpy as np

from time import time
from datetime import timedelta

# %% [markdown]
# ## 1 - Filtered - PCMCI
#
# Filtered - PCMCI (FPCMCI) extends the state-of-the-art causal discovery method PCMCI by augmenting it with a feature-selection method based on Transfer Entropy. The algorithm, starting from a prefixed set of variables, identifies the correct subset of features and possible links between them which describe the observed process. Then, from the selected features and links, a causal model is built.
#
# You can use two types of estimator:
# - Gaussian, able to detect continuous and additive dependencies
# - Kraskov, able to detect continuous and general dependencies

# %% [markdown]
# ## 2 - Example
# Here, a very simple example with a model composed by 5 equations.
# - $X_0$ is linear dependent from $X_1$ and $X_3$;
# - $X_1$ is only uniform noise. It is the confounder of $X_0$ and $X_2$;
# - $X_2$ is non-linear dependent from $X_1$;
# - $X_3$ is linear auto-dependent;
# - $X_4$ is only uniform noise not connected to any other variables.

# %%
alpha = 0.05
min_lag = 1
max_lag = 1
    
np.random.seed(1)
T = 1000
N = 5
d = np.random.random(size = (T, N))
for t in range(max_lag, T):
    d[t, 0] += 2 * d[t-1, 1] + 3 * d[t-1, 2]
    d[t, 2] += 1.1 * d[t-1, 1]**2
    d[t, 3] += d[t-1, 3]
    
df = Data(d)

# %% [markdown]
# a causal model can be reconstructed by using the FPCMCI:

# %%
fpcmci = FPCMCI(df, 
            f_alpha = alpha, 
            pcmci_alpha = alpha, 
            min_lag = min_lag, 
            max_lag = max_lag, 
            sel_method = TE(TEestimator.Gaussian), 
            val_condtest = GPDC(significance = 'analytic', gp_params = None),
            verbosity = CPLevel.DEBUG)
sel_var, cm = fpcmci.run()
fpcmci.dag(label_type = LabelType.Lag, node_layout = 'circular')
# Out:
# -------------------------------------------------------
# Selecting relevant features among: ['X_0', 'X_1', 'X_2', 'X_3', 'X_4']
# Selection method: Transfer Entropy
# Significance level: 0.05
# Max lag time: 1
# Min lag time: 1
# Data length: 1000
#
# ##
# ## Transfer Entropy analysis
# ##
#
# ## Target variable: X_0
# (X_0 -1)             -->      (X_0)     |score: 0.032       |pval: 0.002
# (X_2 -1)             -->      (X_0)     |score: 1.481       |pval: 0.002
# (X_1 -1)             -->      (X_0)     |score: 0.839       |pval: 0.002
#
# ## Target variable: X_1
# (X_3 -1)             -->      (X_1)     |score: 0.003       |pval: 0.028
#
# ## Target variable: X_2
# (X_1 -1)             -->      (X_2)     |score: 0.392       |pval: 0.002
#
# ## Target variable: X_3
# (X_3 -1)             -->      (X_3)     |score: 6.222       |pval: 0.002
#
# ## Target variable: X_4
# no sources selected
#
#
# -------------------------------------------------------
# Running Causal Discovery Algorithm
#
# ##
# ## Step 1: PC1 algorithm with lagged conditions
# ##
#
# Parameters:
# selected_links = {0: [(0, -1), (2, -1), (1, -1)], 1: [(3, -1)], 2: [(1, -1)], 3: [(3, -1)]}
# independence test = gp_dc
# tau_min = 1
# tau_max = 1
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Variable $X_0$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_0$ -1) --> $X_0$ (1/3):
#     Subset 0: () gives pval = 0.00000 / val =  0.241
#     No conditions of dimension 0 left.
#
#     Link ($X_2$ -1) --> $X_0$ (2/3):
#     Subset 0: () gives pval = 0.00000 / val =  0.850
#     No conditions of dimension 0 left.
#
#     Link ($X_1$ -1) --> $X_0$ (3/3):
#     Subset 0: () gives pval = 0.00000 / val =  0.385
#     No conditions of dimension 0 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_0$ has 3 link(s):
#         ($X_2$ -1): max_pval = 0.00000, min_val =  0.850
#         ($X_1$ -1): max_pval = 0.00000, min_val =  0.385
#         ($X_0$ -1): max_pval = 0.00000, min_val =  0.241
#
# Testing condition sets of dimension 1:
#
#     Link ($X_2$ -1) --> $X_0$ (1/3):
#     Subset 0: ($X_1$ -1)  gives pval = 0.00000 / val =  0.964
#     No conditions of dimension 1 left.
#
#     Link ($X_1$ -1) --> $X_0$ (2/3):
#     Subset 0: ($X_2$ -1)  gives pval = 0.00000 / val =  0.891
#     No conditions of dimension 1 left.
#
#     Link ($X_0$ -1) --> $X_0$ (3/3):
#     Subset 0: ($X_2$ -1)  gives pval = 0.52900 / val =  0.045
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_0$ has 2 link(s):
#         ($X_2$ -1): max_pval = 0.00000, min_val =  0.850
#         ($X_1$ -1): max_pval = 0.00000, min_val =  0.385
#
# Algorithm converged for variable $X_0$
#
# ## Variable $X_1$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_3$ -1) --> $X_1$ (1/1):
#     Subset 0: () gives pval = 0.02100 / val =  0.080
#     No conditions of dimension 0 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_1$ has 1 link(s):
#         ($X_3$ -1): max_pval = 0.02100, min_val =  0.080
#
# Algorithm converged for variable $X_1$
#
# ## Variable $X_2$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_1$ -1) --> $X_2$ (1/1):
#     Subset 0: () gives pval = 0.00000 / val =  0.707
#     No conditions of dimension 0 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_2$ has 1 link(s):
#         ($X_1$ -1): max_pval = 0.00000, min_val =  0.707
#
# Algorithm converged for variable $X_2$
#
# ## Variable $X_3$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_3$ -1) --> $X_3$ (1/1):
#     Subset 0: () gives pval = 0.00000 / val =  1.000
#     No conditions of dimension 0 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_3$ has 1 link(s):
#         ($X_3$ -1): max_pval = 0.00000, min_val =  1.000
#
# Algorithm converged for variable $X_3$
#
# ## Resulting lagged parent (super)sets:
#
#     Variable $X_0$ has 2 link(s):
#         ($X_2$ -1): max_pval = 0.00000, min_val =  0.850
#         ($X_1$ -1): max_pval = 0.00000, min_val =  0.385
#
#     Variable $X_1$ has 1 link(s):
#         ($X_3$ -1): max_pval = 0.02100, min_val =  0.080
#
#     Variable $X_2$ has 1 link(s):
#         ($X_1$ -1): max_pval = 0.00000, min_val =  0.707
#
#     Variable $X_3$ has 1 link(s):
#         ($X_3$ -1): max_pval = 0.00000, min_val =  1.000
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = gp_dc
# tau_min = 1
# tau_max = 1
# max_conds_py = None
# max_conds_px = None
#
#         link ($X_0$ -1) --> $X_0$ (1/3):
#         with conds_y = [ ($X_2$ -1) ($X_1$ -1) ]
#         with conds_x = [ ($X_2$ -2) ($X_1$ -2) ]
#
#         link ($X_2$ -1) --> $X_0$ (2/3):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ($X_1$ -2) ]
#
#         link ($X_1$ -1) --> $X_0$ (3/3):
#         with conds_y = [ ($X_2$ -1) ]
#         with conds_x = [ ($X_3$ -2) ]
#
#         link ($X_3$ -1) --> $X_1$ (1/1):
#         with conds_y = [ ]
#         with conds_x = [ ($X_3$ -2) ]
#
#         link ($X_1$ -1) --> $X_2$ (1/1):
#         with conds_y = [ ]
#         with conds_x = [ ($X_3$ -2) ]
#
#         link ($X_3$ -1) --> $X_3$ (1/1):
#         with conds_y = [ ]
#         with conds_x = [ ($X_3$ -2) ]
#
# ## Significant links at alpha = 0.05:
#
#     Variable $X_0$ has 2 link(s):
#         ($X_2$ -1): pval = 0.00000 | val =  0.938
#         ($X_1$ -1): pval = 0.00000 | val =  0.887
#
#     Variable $X_1$ has 0 link(s):
#
#     Variable $X_2$ has 1 link(s):
#         ($X_1$ -1): pval = 0.00000 | val =  0.706
#
#     Variable $X_3$ has 1 link(s):
#         ($X_3$ -1): pval = 0.00000 | val =  0.647
# -------------------------------------------------------
# Difference(s)
# -------------------------------------------------------
# Removing (X_0 -1) --> (X_0)
# Removing (X_3 -1) --> (X_1)
#
# Feature selected: ['X_0', 'X_1', 'X_2', 'X_3']

# %% [markdown]
# As you can see, since $X_4$ does not depend and does not affect any other variable, it has been removed. Moreover, by setting `neglect_only_autodep = True`, you can also neglect the variable that are auto-dependent but are not connectect to any other variables.

# %%
fpcmci = FPCMCI(df, 
            f_alpha = alpha, 
            pcmci_alpha = alpha, 
            min_lag = min_lag, 
            max_lag = max_lag, 
            sel_method = TE(TEestimator.Gaussian), 
            val_condtest = GPDC(significance = 'analytic', gp_params = None),
            verbosity = CPLevel.DEBUG,
            neglect_only_autodep = True)
sel_var, cm = fpcmci.run()
fpcmci.dag(label_type = LabelType.Lag, node_layout = 'circular')
# Out:
# -------------------------------------------------------
# Selecting relevant features among: ['X_0', 'X_1', 'X_2', 'X_3']
# Selection method: Transfer Entropy
# Significance level: 0.05
# Max lag time: 1
# Min lag time: 1
# Data length: 1000
#
# ##
# ## Transfer Entropy analysis
# ##
#
# ## Target variable: X_0
# (X_0 -1)             -->      (X_0)     |score: 0.032       |pval: 0.002
# (X_2 -1)             -->      (X_0)     |score: 1.481       |pval: 0.002
# (X_1 -1)             -->      (X_0)     |score: 0.839       |pval: 0.002
#
# ## Target variable: X_1
# (X_3 -1)             -->      (X_1)     |score: 0.003       |pval: 0.018
#
# ## Target variable: X_2
# (X_1 -1)             -->      (X_2)     |score: 0.392       |pval: 0.002
#
# ## Target variable: X_3
# (X_3 -1)             -->      (X_3)     |score: 6.222       |pval: 0.002
#
#
# -------------------------------------------------------
# Running Causal Discovery Algorithm
#
# ##
# ## Step 1: PC1 algorithm with lagged conditions
# ##
#
# Parameters:
# selected_links = {0: [(0, -1), (2, -1), (1, -1)], 1: [(3, -1)], 2: [(1, -1)], 3: [(3, -1)]}
# independence test = gp_dc
# tau_min = 1
# tau_max = 1
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Variable $X_0$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_0$ -1) --> $X_0$ (1/3):
#     Subset 0: () gives pval = 0.00000 / val =  0.241
#     No conditions of dimension 0 left.
#
#     Link ($X_2$ -1) --> $X_0$ (2/3):
#     Subset 0: () gives pval = 0.00000 / val =  0.850
#     No conditions of dimension 0 left.
#
#     Link ($X_1$ -1) --> $X_0$ (3/3):
#     Subset 0: () gives pval = 0.00000 / val =  0.385
#     No conditions of dimension 0 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_0$ has 3 link(s):
#         ($X_2$ -1): max_pval = 0.00000, min_val =  0.850
#         ($X_1$ -1): max_pval = 0.00000, min_val =  0.385
#         ($X_0$ -1): max_pval = 0.00000, min_val =  0.241
#
# Testing condition sets of dimension 1:
#
#     Link ($X_2$ -1) --> $X_0$ (1/3):
#     Subset 0: ($X_1$ -1)  gives pval = 0.00000 / val =  0.964
#     No conditions of dimension 1 left.
#
#     Link ($X_1$ -1) --> $X_0$ (2/3):
#     Subset 0: ($X_2$ -1)  gives pval = 0.00000 / val =  0.891
#     No conditions of dimension 1 left.
#
#     Link ($X_0$ -1) --> $X_0$ (3/3):
#     Subset 0: ($X_2$ -1)  gives pval = 0.52900 / val =  0.045
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_0$ has 2 link(s):
#         ($X_2$ -1): max_pval = 0.00000, min_val =  0.850
#         ($X_1$ -1): max_pval = 0.00000, min_val =  0.385
#
# Algorithm converged for variable $X_0$
#
# ## Variable $X_1$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_3$ -1) --> $X_1$ (1/1):
#     Subset 0: () gives pval = 0.02100 / val =  0.080
#     No conditions of dimension 0 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_1$ has 1 link(s):
#         ($X_3$ -1): max_pval = 0.02100, min_val =  0.080
#
# Algorithm converged for variable $X_1$
#
# ## Variable $X_2$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_1$ -1) --> $X_2$ (1/1):
#     Subset 0: () gives pval = 0.00000 / val =  0.707
#     No conditions of dimension 0 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_2$ has 1 link(s):
#         ($X_1$ -1): max_pval = 0.00000, min_val =  0.707
#
# Algorithm converged for variable $X_2$
#
# ## Variable $X_3$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_3$ -1) --> $X_3$ (1/1):
#     Subset 0: () gives pval = 0.00000 / val =  1.000
#     No conditions of dimension 0 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_3$ has 1 link(s):
#         ($X_3$ -1): max_pval = 0.00000, min_val =  1.000
#
# Algorithm converged for variable $X_3$
#
# ## Resulting lagged parent (super)sets:
#
#     Variable $X_0$ has 2 link(s):
#         ($X_2$ -1): max_pval = 0.00000, min_val =  0.850
#         ($X_1$ -1): max_pval = 0.00000, min_val =  0.385
#
#     Variable $X_1$ has 1 link(s):
#         ($X_3$ -1): max_pval = 0.02100, min_val =  0.080
#
#     Variable $X_2$ has 1 link(s):
#         ($X_1$ -1): max_pval = 0.00000, min_val =  0.707
#
#     Variable $X_3$ has 1 link(s):
#         ($X_3$ -1): max_pval = 0.00000, min_val =  1.000
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = gp_dc
# tau_min = 1
# tau_max = 1
# max_conds_py = None
# max_conds_px = None
#
#         link ($X_0$ -1) --> $X_0$ (1/3):
#         with conds_y = [ ($X_2$ -1) ($X_1$ -1) ]
#         with conds_x = [ ($X_2$ -2) ($X_1$ -2) ]
#
#         link ($X_2$ -1) --> $X_0$ (2/3):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ($X_1$ -2) ]
#
#         link ($X_1$ -1) --> $X_0$ (3/3):
#         with conds_y = [ ($X_2$ -1) ]
#         with conds_x = [ ($X_3$ -2) ]
#
#         link ($X_3$ -1) --> $X_1$ (1/1):
#         with conds_y = [ ]
#         with conds_x = [ ($X_3$ -2) ]
#
#         link ($X_1$ -1) --> $X_2$ (1/1):
#         with conds_y = [ ]
#         with conds_x = [ ($X_3$ -2) ]
#
#         link ($X_3$ -1) --> $X_3$ (1/1):
#         with conds_y = [ ]
#         with conds_x = [ ($X_3$ -2) ]
#
# ## Significant links at alpha = 0.05:
#
#     Variable $X_0$ has 2 link(s):
#         ($X_2$ -1): pval = 0.00000 | val =  0.938
#         ($X_1$ -1): pval = 0.00000 | val =  0.887
#
#     Variable $X_1$ has 0 link(s):
#
#     Variable $X_2$ has 1 link(s):
#         ($X_1$ -1): pval = 0.00000 | val =  0.706
#
#     Variable $X_3$ has 1 link(s):
#         ($X_3$ -1): pval = 0.00000 | val =  0.647
# -------------------------------------------------------
# Difference(s)
# -------------------------------------------------------
# Removing (X_0 -1) --> (X_0)
# Removing (X_3 -1) --> (X_1)
#
# Feature selected: ['X_0', 'X_1', 'X_2']

# %% [markdown]
# ## 3 - FPCMCI vs PCMCI
# Here, we compare the two algorithms, FPCMCI and PCMCI, on the same data under the point of view of executional time and accuracy of the causal model.
# <br><br>
# First of all, we need to generate data. We can do it as follows:

# %%
alpha = 0.05
min_lag = 1
max_lag = 2
    
np.random.seed(1)
T = 1500
N = 7
d = np.random.random(size = (T, N))
for t in range(max_lag, T):
    d[t, 0] += 2 * d[t-1, 1] + 3 * d[t-2, 3]
    d[t, 2] += 1.1 * d[t-1, 1]**2
    d[t, 3] += d[t-1, 3] * d[t-2, 2]
    d[t, 4] += d[t-2, 4] + d[t-2, 5] * d[t-1, 0]
        
df = Data(d)

# %% [markdown]
# Then, a causal model can be computed by using the FPCMCI:

# %%
start = time()
fpcmci = FPCMCI(df, 
            f_alpha = alpha, 
            pcmci_alpha = alpha, 
            min_lag = min_lag, 
            max_lag = max_lag, 
            sel_method = TE(TEestimator.Gaussian), 
            val_condtest = GPDC(significance = 'analytic', gp_params = None),
            verbosity = CPLevel.DEBUG)
    
sel_var, cm = fpcmci.run()
elapsed_FPCMCI = time() - start
print("FPCMCI executional time: " + str(timedelta(seconds = elapsed_FPCMCI)))
fpcmci.dag(label_type = LabelType.Lag, node_layout = 'circular')
# Out:
# -------------------------------------------------------
# Selecting relevant features among: ['X_0', 'X_1', 'X_2', 'X_3', 'X_4', 'X_5', 'X_6']
# Selection method: Transfer Entropy
# Significance level: 0.05
# Max lag time: 2
# Min lag time: 1
# Data length: 1500
#
# ##
# ## Transfer Entropy analysis
# ##
#
# ## Target variable: X_0
# (X_0 -1)             -->      (X_0)     |score: 0.174       |pval: 0.002
# (X_0 -2)             -->      (X_0)     |score: 0.033       |pval: 0.002
# (X_3 -2)             -->      (X_0)     |score: 3.822       |pval: 0.002
# (X_1 -1)             -->      (X_0)     |score: 0.844       |pval: 0.002
#
# ## Target variable: X_1
# no sources selected
#
# ## Target variable: X_2
# (X_1 -1)             -->      (X_2)     |score: 0.389       |pval: 0.002
#
# ## Target variable: X_3
# (X_3 -1)             -->      (X_3)     |score: 0.175       |pval: 0.002
# (X_3 -2)             -->      (X_3)     |score: 0.032       |pval: 0.002
# (X_2 -2)             -->      (X_3)     |score: 0.128       |pval: 0.002
# (X_0 -1)             -->      (X_3)     |score: 0.016       |pval: 0.002
# (X_0 -2)             -->      (X_3)     |score: 0.007       |pval: 0.002
#
# ## Target variable: X_4
# (X_4 -2)             -->      (X_4)     |score: 4.715       |pval: 0.002
# (X_0 -1)             -->      (X_4)     |score: 0.670       |pval: 0.002
# (X_5 -2)             -->      (X_4)     |score: 0.166       |pval: 0.002
# (X_3 -1)             -->      (X_4)     |score: 0.041       |pval: 0.002
#
# ## Target variable: X_5
# no sources selected
#
# ## Target variable: X_6
# no sources selected
#
#
# -------------------------------------------------------
# Running Causal Discovery Algorithm
#
# ##
# ## Step 1: PC1 algorithm with lagged conditions
# ##
#
# Parameters:
# selected_links = {0: [(0, -1), (0, -2), (3, -2), (1, -1)], 1: [], 2: [(1, -1)], 3: [(3, -1), (3, -2), (2, -2), (0, -1), (0, -2)], 4: [(4, -2), (0, -1), (5, -2), (3, -1)], 5: []}
# independence test = gp_dc
# tau_min = 1
# tau_max = 2
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Variable $X_0$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_0$ -1) --> $X_0$ (1/4):
#     Subset 0: () gives pval = 0.00000 / val =  0.736
#     No conditions of dimension 0 left.
#
#     Link ($X_0$ -2) --> $X_0$ (2/4):
#     Subset 0: () gives pval = 0.00000 / val =  0.570
#     No conditions of dimension 0 left.
#
#     Link ($X_3$ -2) --> $X_0$ (3/4):
#     Subset 0: () gives pval = 0.00000 / val =  0.987
#     No conditions of dimension 0 left.
#
#     Link ($X_1$ -1) --> $X_0$ (4/4):
#     Subset 0: () gives pval = 0.00100 / val =  0.085
#     No conditions of dimension 0 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_0$ has 4 link(s):
#         ($X_3$ -2): max_pval = 0.00000, min_val =  0.987
#         ($X_0$ -1): max_pval = 0.00000, min_val =  0.736
#         ($X_0$ -2): max_pval = 0.00000, min_val =  0.570
#         ($X_1$ -1): max_pval = 0.00100, min_val =  0.085
#
# Testing condition sets of dimension 1:
#
#     Link ($X_3$ -2) --> $X_0$ (1/4):
#     Subset 0: ($X_0$ -1)  gives pval = 0.00000 / val =  0.974
#     No conditions of dimension 1 left.
#
#     Link ($X_0$ -1) --> $X_0$ (2/4):
#     Subset 0: ($X_3$ -2)  gives pval = 0.14700 / val =  0.051
#     Non-significance detected.
#
#     Link ($X_0$ -2) --> $X_0$ (3/4):
#     Subset 0: ($X_3$ -2)  gives pval = 0.01600 / val =  0.069
#     No conditions of dimension 1 left.
#
#     Link ($X_1$ -1) --> $X_0$ (4/4):
#     Subset 0: ($X_3$ -2)  gives pval = 0.00000 / val =  0.887
#     No conditions of dimension 1 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_0$ has 3 link(s):
#         ($X_3$ -2): max_pval = 0.00000, min_val =  0.974
#         ($X_1$ -1): max_pval = 0.00100, min_val =  0.085
#         ($X_0$ -2): max_pval = 0.01600, min_val =  0.069
#
# Testing condition sets of dimension 2:
#
#     Link ($X_3$ -2) --> $X_0$ (1/3):
#     Subset 0: ($X_1$ -1) ($X_0$ -2)  gives pval = 0.00000 / val =  0.997
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_1$ -1) --> $X_0$ (2/3):
#     Subset 0: ($X_3$ -2) ($X_0$ -2)  gives pval = 0.00000 / val =  0.886
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_0$ -2) --> $X_0$ (3/3):
#     Subset 0: ($X_3$ -2) ($X_1$ -1)  gives pval = 0.83800 / val =  0.030
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_0$ has 2 link(s):
#         ($X_3$ -2): max_pval = 0.00000, min_val =  0.974
#         ($X_1$ -1): max_pval = 0.00100, min_val =  0.085
#
# Algorithm converged for variable $X_0$
#
# ## Variable $X_1$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Algorithm converged for variable $X_1$
#
# ## Variable $X_2$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_1$ -1) --> $X_2$ (1/1):
#     Subset 0: () gives pval = 0.00000 / val =  0.693
#     No conditions of dimension 0 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_2$ has 1 link(s):
#         ($X_1$ -1): max_pval = 0.00000, min_val =  0.693
#
# Algorithm converged for variable $X_2$
#
# ## Variable $X_3$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_3$ -1) --> $X_3$ (1/5):
#     Subset 0: () gives pval = 0.00000 / val =  0.748
#     No conditions of dimension 0 left.
#
#     Link ($X_3$ -2) --> $X_3$ (2/5):
#     Subset 0: () gives pval = 0.00000 / val =  0.571
#     No conditions of dimension 0 left.
#
#     Link ($X_2$ -2) --> $X_3$ (3/5):
#     Subset 0: () gives pval = 0.00000 / val =  0.529
#     No conditions of dimension 0 left.
#
#     Link ($X_0$ -1) --> $X_3$ (4/5):
#     Subset 0: () gives pval = 0.00000 / val =  0.437
#     No conditions of dimension 0 left.
#
#     Link ($X_0$ -2) --> $X_3$ (5/5):
#     Subset 0: () gives pval = 0.00000 / val =  0.367
#     No conditions of dimension 0 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_3$ has 5 link(s):
#         ($X_3$ -1): max_pval = 0.00000, min_val =  0.748
#         ($X_3$ -2): max_pval = 0.00000, min_val =  0.571
#         ($X_2$ -2): max_pval = 0.00000, min_val =  0.529
#         ($X_0$ -1): max_pval = 0.00000, min_val =  0.437
#         ($X_0$ -2): max_pval = 0.00000, min_val =  0.367
#
# Testing condition sets of dimension 1:
#
#     Link ($X_3$ -1) --> $X_3$ (1/5):
#     Subset 0: ($X_3$ -2)  gives pval = 0.00000 / val =  0.515
#     No conditions of dimension 1 left.
#
#     Link ($X_3$ -2) --> $X_3$ (2/5):
#     Subset 0: ($X_3$ -1)  gives pval = 0.00800 / val =  0.074
#     No conditions of dimension 1 left.
#
#     Link ($X_2$ -2) --> $X_3$ (3/5):
#     Subset 0: ($X_3$ -1)  gives pval = 0.00000 / val =  0.877
#     No conditions of dimension 1 left.
#
#     Link ($X_0$ -1) --> $X_3$ (4/5):
#     Subset 0: ($X_3$ -1)  gives pval = 0.00500 / val =  0.077
#     No conditions of dimension 1 left.
#
#     Link ($X_0$ -2) --> $X_3$ (5/5):
#     Subset 0: ($X_3$ -1)  gives pval = 0.00200 / val =  0.078
#     No conditions of dimension 1 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_3$ has 5 link(s):
#         ($X_2$ -2): max_pval = 0.00000, min_val =  0.529
#         ($X_3$ -1): max_pval = 0.00000, min_val =  0.515
#         ($X_0$ -2): max_pval = 0.00200, min_val =  0.078
#         ($X_0$ -1): max_pval = 0.00500, min_val =  0.077
#         ($X_3$ -2): max_pval = 0.00800, min_val =  0.074
#
# Testing condition sets of dimension 2:
#
#     Link ($X_2$ -2) --> $X_3$ (1/5):
#     Subset 0: ($X_3$ -1) ($X_0$ -2)  gives pval = 0.00000 / val =  0.873
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_3$ -1) --> $X_3$ (2/5):
#     Subset 0: ($X_2$ -2) ($X_0$ -2)  gives pval = 0.00000 / val =  0.859
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_0$ -2) --> $X_3$ (3/5):
#     Subset 0: ($X_2$ -2) ($X_3$ -1)  gives pval = 0.52500 / val =  0.037
#     Non-significance detected.
#
#     Link ($X_0$ -1) --> $X_3$ (4/5):
#     Subset 0: ($X_2$ -2) ($X_3$ -1)  gives pval = 0.78500 / val =  0.032
#     Non-significance detected.
#
#     Link ($X_3$ -2) --> $X_3$ (5/5):
#     Subset 0: ($X_2$ -2) ($X_3$ -1)  gives pval = 0.47100 / val =  0.038
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_3$ has 2 link(s):
#         ($X_2$ -2): max_pval = 0.00000, min_val =  0.529
#         ($X_3$ -1): max_pval = 0.00000, min_val =  0.515
#
# Algorithm converged for variable $X_3$
#
# ## Variable $X_4$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_4$ -2) --> $X_4$ (1/4):
#     Subset 0: () gives pval = 0.00000 / val =  1.000
#     No conditions of dimension 0 left.
#
#     Link ($X_0$ -1) --> $X_4$ (2/4):
#     Subset 0: () gives pval = 0.00200 / val =  0.079
#     No conditions of dimension 0 left.
#
#     Link ($X_5$ -2) --> $X_4$ (3/4):
#     Subset 0: () gives pval = 0.02800 / val =  0.063
#     No conditions of dimension 0 left.
#
#     Link ($X_3$ -1) --> $X_4$ (4/4):
#     Subset 0: () gives pval = 0.00200 / val =  0.078
#     No conditions of dimension 0 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_4$ has 4 link(s):
#         ($X_4$ -2): max_pval = 0.00000, min_val =  1.000
#         ($X_0$ -1): max_pval = 0.00200, min_val =  0.079
#         ($X_3$ -1): max_pval = 0.00200, min_val =  0.078
#         ($X_5$ -2): max_pval = 0.02800, min_val =  0.063
#
# Testing condition sets of dimension 1:
#
#     Link ($X_4$ -2) --> $X_4$ (1/4):
#     Subset 0: ($X_0$ -1)  gives pval = 0.00000 / val =  0.997
#     No conditions of dimension 1 left.
#
#     Link ($X_0$ -1) --> $X_4$ (2/4):
#     Subset 0: ($X_4$ -2)  gives pval = 0.00000 / val =  0.564
#     No conditions of dimension 1 left.
#
#     Link ($X_3$ -1) --> $X_4$ (3/4):
#     Subset 0: ($X_4$ -2)  gives pval = 0.00000 / val =  0.242
#     No conditions of dimension 1 left.
#
#     Link ($X_5$ -2) --> $X_4$ (4/4):
#     Subset 0: ($X_4$ -2)  gives pval = 0.00000 / val =  0.635
#     No conditions of dimension 1 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_4$ has 4 link(s):
#         ($X_4$ -2): max_pval = 0.00000, min_val =  0.997
#         ($X_0$ -1): max_pval = 0.00200, min_val =  0.079
#         ($X_3$ -1): max_pval = 0.00200, min_val =  0.078
#         ($X_5$ -2): max_pval = 0.02800, min_val =  0.063
#
# Testing condition sets of dimension 2:
#
#     Link ($X_4$ -2) --> $X_4$ (1/4):
#     Subset 0: ($X_0$ -1) ($X_3$ -1)  gives pval = 0.00000 / val =  1.000
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_0$ -1) --> $X_4$ (2/4):
#     Subset 0: ($X_4$ -2) ($X_3$ -1)  gives pval = 0.00000 / val =  0.499
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_3$ -1) --> $X_4$ (3/4):
#     Subset 0: ($X_4$ -2) ($X_0$ -1)  gives pval = 0.00000 / val =  0.103
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_5$ -2) --> $X_4$ (4/4):
#     Subset 0: ($X_4$ -2) ($X_0$ -1)  gives pval = 0.00000 / val =  0.907
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_4$ has 4 link(s):
#         ($X_4$ -2): max_pval = 0.00000, min_val =  0.997
#         ($X_0$ -1): max_pval = 0.00200, min_val =  0.079
#         ($X_3$ -1): max_pval = 0.00200, min_val =  0.078
#         ($X_5$ -2): max_pval = 0.02800, min_val =  0.063
#
# Testing condition sets of dimension 3:
#
#     Link ($X_4$ -2) --> $X_4$ (1/4):
#     Subset 0: ($X_0$ -1) ($X_3$ -1) ($X_5$ -2)  gives pval = 0.00000 / val =  1.000
#     Still subsets of dimension 3 left, but q_max = 1 reached.
#
#     Link ($X_0$ -1) --> $X_4$ (2/4):
#     Subset 0: ($X_4$ -2) ($X_3$ -1) ($X_5$ -2)  gives pval = 0.00000 / val =  0.736
#     Still subsets of dimension 3 left, but q_max = 1 reached.
#
#     Link ($X_3$ -1) --> $X_4$ (3/4):
#     Subset 0: ($X_4$ -2) ($X_0$ -1) ($X_5$ -2)  gives pval = 0.09100 / val =  0.055
#     Non-significance detected.
#
#     Link ($X_5$ -2) --> $X_4$ (4/4):
#     Subset 0: ($X_4$ -2) ($X_0$ -1) ($X_3$ -1)  gives pval = 0.00000 / val =  0.908
#     Still subsets of dimension 3 left, but q_max = 1 reached.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_4$ has 3 link(s):
#         ($X_4$ -2): max_pval = 0.00000, min_val =  0.997
#         ($X_0$ -1): max_pval = 0.00200, min_val =  0.079
#         ($X_5$ -2): max_pval = 0.02800, min_val =  0.063
#
# Algorithm converged for variable $X_4$
#
# ## Variable $X_5$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Algorithm converged for variable $X_5$
#
# ## Resulting lagged parent (super)sets:
#
#     Variable $X_0$ has 2 link(s):
#         ($X_3$ -2): max_pval = 0.00000, min_val =  0.987
#         ($X_1$ -1): max_pval = 0.00100, min_val =  0.085
#
#     Variable $X_1$ has 0 link(s):
#
#     Variable $X_2$ has 1 link(s):
#         ($X_1$ -1): max_pval = 0.00000, min_val =  0.693
#
#     Variable $X_3$ has 2 link(s):
#         ($X_2$ -2): max_pval = 0.00000, min_val =  0.529
#         ($X_3$ -1): max_pval = 0.00000, min_val =  0.748
#
#     Variable $X_4$ has 3 link(s):
#         ($X_4$ -2): max_pval = 0.00000, min_val =  1.000
#         ($X_0$ -1): max_pval = 0.00200, min_val =  0.079
#         ($X_5$ -2): max_pval = 0.02800, min_val =  0.063
#
#     Variable $X_5$ has 0 link(s):
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = gp_dc
# tau_min = 1
# tau_max = 2
# max_conds_py = None
# max_conds_px = None
#
#         link ($X_0$ -1) --> $X_0$ (1/4):
#         with conds_y = [ ($X_3$ -2) ($X_1$ -1) ]
#         with conds_x = [ ($X_3$ -3) ($X_1$ -2) ]
#
#         link ($X_0$ -2) --> $X_0$ (2/4):
#         with conds_y = [ ($X_3$ -2) ($X_1$ -1) ]
#         with conds_x = [ ($X_3$ -4) ($X_1$ -3) ]
#
#         link ($X_3$ -2) --> $X_0$ (3/4):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ($X_2$ -4) ($X_3$ -3) ]
#
#         link ($X_1$ -1) --> $X_0$ (4/4):
#         with conds_y = [ ($X_3$ -2) ]
#         with conds_x = [ ]
#
#         link ($X_1$ -1) --> $X_2$ (1/1):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link ($X_3$ -1) --> $X_3$ (1/5):
#         with conds_y = [ ($X_2$ -2) ]
#         with conds_x = [ ($X_2$ -3) ($X_3$ -2) ]
#
#         link ($X_3$ -2) --> $X_3$ (2/5):
#         with conds_y = [ ($X_2$ -2) ($X_3$ -1) ]
#         with conds_x = [ ($X_2$ -4) ($X_3$ -3) ]
#
#         link ($X_2$ -2) --> $X_3$ (3/5):
#         with conds_y = [ ($X_3$ -1) ]
#         with conds_x = [ ($X_1$ -3) ]
#
#         link ($X_0$ -1) --> $X_3$ (4/5):
#         with conds_y = [ ($X_2$ -2) ($X_3$ -1) ]
#         with conds_x = [ ($X_3$ -3) ($X_1$ -2) ]
#
#         link ($X_0$ -2) --> $X_3$ (5/5):
#         with conds_y = [ ($X_2$ -2) ($X_3$ -1) ]
#         with conds_x = [ ($X_3$ -4) ($X_1$ -3) ]
#
#         link ($X_4$ -2) --> $X_4$ (1/4):
#         with conds_y = [ ($X_0$ -1) ($X_5$ -2) ]
#         with conds_x = [ ($X_4$ -4) ($X_0$ -3) ($X_5$ -4) ]
#
#         link ($X_0$ -1) --> $X_4$ (2/4):
#         with conds_y = [ ($X_4$ -2) ($X_5$ -2) ]
#         with conds_x = [ ($X_3$ -3) ($X_1$ -2) ]
#
#         link ($X_5$ -2) --> $X_4$ (3/4):
#         with conds_y = [ ($X_4$ -2) ($X_0$ -1) ]
#         with conds_x = [ ]
#
#         link ($X_3$ -1) --> $X_4$ (4/4):
#         with conds_y = [ ($X_4$ -2) ($X_0$ -1) ($X_5$ -2) ]
#         with conds_x = [ ($X_2$ -3) ($X_3$ -2) ]
#
# ## Significant links at alpha = 0.05:
#
#     Variable $X_0$ has 2 link(s):
#         ($X_3$ -2): pval = 0.00000 | val =  0.947
#         ($X_1$ -1): pval = 0.00000 | val =  0.887
#
#     Variable $X_1$ has 0 link(s):
#
#     Variable $X_2$ has 1 link(s):
#         ($X_1$ -1): pval = 0.00000 | val =  0.693
#
#     Variable $X_3$ has 2 link(s):
#         ($X_2$ -2): pval = 0.00000 | val =  0.818
#         ($X_3$ -1): pval = 0.00000 | val =  0.533
#
#     Variable $X_4$ has 3 link(s):
#         ($X_5$ -2): pval = 0.00000 | val =  0.907
#         ($X_4$ -2): pval = 0.00000 | val =  0.754
#         ($X_0$ -1): pval = 0.00000 | val =  0.303
#
#     Variable $X_5$ has 0 link(s):
# -------------------------------------------------------
# Difference(s)
# -------------------------------------------------------
# Removing (X_0 -1) --> (X_0)
# Removing (X_0 -2) --> (X_0)
# Removing (X_3 -2) --> (X_3)
# Removing (X_0 -1) --> (X_3)
# Removing (X_0 -2) --> (X_3)
# Removing (X_3 -1) --> (X_4)
#
# Feature selected: ['X_0', 'X_1', 'X_2', 'X_3', 'X_4', 'X_5']
# FPCMCI executional time: 0:06:29.892177

# %% [markdown]
# As you can see, $X_6$ has been removed because it does not depend and does not affect any other variable.
# Now, we can perform the same analysis by using the PCMCI causal discovery algorithm:

# %%
start = time()
fpcmci = FPCMCI(df, 
            pcmci_alpha = alpha, 
            min_lag = min_lag, 
            max_lag = max_lag, 
            sel_method = TE(TEestimator.Gaussian), 
            val_condtest = GPDC(significance = 'analytic', gp_params = None),
            verbosity = CPLevel.DEBUG)
sel_var, cm = fpcmci.run_pcmci()
elapsed_PCMCI = time() - start
print("PCMCI executional time: " + str(timedelta(seconds = elapsed_PCMCI)))
fpcmci.dag(label_type = LabelType.Lag, node_layout = 'circular')
# Out:
# Significance level: 0.05
# Max lag time: 2
# Min lag time: 1
# Data length: 1500
#
#
# -------------------------------------------------------
# Running Causal Discovery Algorithm
#
# ##
# ## Step 1: PC1 algorithm with lagged conditions
# ##
#
# Parameters:
# independence test = gp_dc
# tau_min = 1
# tau_max = 2
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Variable $X_0$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_0$ -1) --> $X_0$ (1/14):
#     Subset 0: () gives pval = 0.00000 / val =  0.736
#     No conditions of dimension 0 left.
#
#     Link ($X_0$ -2) --> $X_0$ (2/14):
#     Subset 0: () gives pval = 0.00000 / val =  0.570
#     No conditions of dimension 0 left.
#
#     Link ($X_1$ -1) --> $X_0$ (3/14):
#     Subset 0: () gives pval = 0.00100 / val =  0.085
#     No conditions of dimension 0 left.
#
#     Link ($X_1$ -2) --> $X_0$ (4/14):
#     Subset 0: () gives pval = 0.23200 / val =  0.046
#     Non-significance detected.
#
#     Link ($X_2$ -1) --> $X_0$ (5/14):
#     Subset 0: () gives pval = 0.82300 / val =  0.031
#     Non-significance detected.
#
#     Link ($X_2$ -2) --> $X_0$ (6/14):
#     Subset 0: () gives pval = 0.69600 / val =  0.033
#     Non-significance detected.
#
#     Link ($X_3$ -1) --> $X_0$ (7/14):
#     Subset 0: () gives pval = 0.00000 / val =  0.740
#     No conditions of dimension 0 left.
#
#     Link ($X_3$ -2) --> $X_0$ (8/14):
#     Subset 0: () gives pval = 0.00000 / val =  0.987
#     No conditions of dimension 0 left.
#
#     Link ($X_4$ -1) --> $X_0$ (9/14):
#     Subset 0: () gives pval = 0.00200 / val =  0.079
#     No conditions of dimension 0 left.
#
#     Link ($X_4$ -2) --> $X_0$ (10/14):
#     Subset 0: () gives pval = 0.00500 / val =  0.076
#     No conditions of dimension 0 left.
#
#     Link ($X_5$ -1) --> $X_0$ (11/14):
#     Subset 0: () gives pval = 0.74600 / val =  0.032
#     Non-significance detected.
#
#     Link ($X_5$ -2) --> $X_0$ (12/14):
#     Subset 0: () gives pval = 0.91100 / val =  0.029
#     Non-significance detected.
#
#     Link ($X_6$ -1) --> $X_0$ (13/14):
#     Subset 0: () gives pval = 0.40200 / val =  0.040
#     Non-significance detected.
#
#     Link ($X_6$ -2) --> $X_0$ (14/14):
#     Subset 0: () gives pval = 0.52500 / val =  0.037
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_0$ has 7 link(s):
#         ($X_3$ -2): max_pval = 0.00000, min_val =  0.987
#         ($X_3$ -1): max_pval = 0.00000, min_val =  0.740
#         ($X_0$ -1): max_pval = 0.00000, min_val =  0.736
#         ($X_0$ -2): max_pval = 0.00000, min_val =  0.570
#         ($X_1$ -1): max_pval = 0.00100, min_val =  0.085
#         ($X_4$ -1): max_pval = 0.00200, min_val =  0.079
#         ($X_4$ -2): max_pval = 0.00500, min_val =  0.076
#
# Testing condition sets of dimension 1:
#
#     Link ($X_3$ -2) --> $X_0$ (1/7):
#     Subset 0: ($X_3$ -1)  gives pval = 0.00000 / val =  0.966
#     No conditions of dimension 1 left.
#
#     Link ($X_3$ -1) --> $X_0$ (2/7):
#     Subset 0: ($X_3$ -2)  gives pval = 0.63300 / val =  0.035
#     Non-significance detected.
#
#     Link ($X_0$ -1) --> $X_0$ (3/7):
#     Subset 0: ($X_3$ -2)  gives pval = 0.14700 / val =  0.051
#     Non-significance detected.
#
#     Link ($X_0$ -2) --> $X_0$ (4/7):
#     Subset 0: ($X_3$ -2)  gives pval = 0.01600 / val =  0.069
#     No conditions of dimension 1 left.
#
#     Link ($X_1$ -1) --> $X_0$ (5/7):
#     Subset 0: ($X_3$ -2)  gives pval = 0.00000 / val =  0.887
#     No conditions of dimension 1 left.
#
#     Link ($X_4$ -1) --> $X_0$ (6/7):
#     Subset 0: ($X_3$ -2)  gives pval = 0.86300 / val =  0.030
#     Non-significance detected.
#
#     Link ($X_4$ -2) --> $X_0$ (7/7):
#     Subset 0: ($X_3$ -2)  gives pval = 0.95600 / val =  0.027
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_0$ has 3 link(s):
#         ($X_3$ -2): max_pval = 0.00000, min_val =  0.966
#         ($X_1$ -1): max_pval = 0.00100, min_val =  0.085
#         ($X_0$ -2): max_pval = 0.01600, min_val =  0.069
#
# Testing condition sets of dimension 2:
#
#     Link ($X_3$ -2) --> $X_0$ (1/3):
#     Subset 0: ($X_1$ -1) ($X_0$ -2)  gives pval = 0.00000 / val =  0.997
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_1$ -1) --> $X_0$ (2/3):
#     Subset 0: ($X_3$ -2) ($X_0$ -2)  gives pval = 0.00000 / val =  0.886
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_0$ -2) --> $X_0$ (3/3):
#     Subset 0: ($X_3$ -2) ($X_1$ -1)  gives pval = 0.83800 / val =  0.030
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_0$ has 2 link(s):
#         ($X_3$ -2): max_pval = 0.00000, min_val =  0.966
#         ($X_1$ -1): max_pval = 0.00100, min_val =  0.085
#
# Algorithm converged for variable $X_0$
#
# ## Variable $X_1$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_0$ -1) --> $X_1$ (1/14):
#     Subset 0: () gives pval = 0.70200 / val =  0.033
#     Non-significance detected.
#
#     Link ($X_0$ -2) --> $X_1$ (2/14):
#     Subset 0: () gives pval = 0.92900 / val =  0.028
#     Non-significance detected.
#
#     Link ($X_1$ -1) --> $X_1$ (3/14):
#     Subset 0: () gives pval = 0.38100 / val =  0.041
#     Non-significance detected.
#
#     Link ($X_1$ -2) --> $X_1$ (4/14):
#     Subset 0: () gives pval = 0.40000 / val =  0.040
#     Non-significance detected.
#
#     Link ($X_2$ -1) --> $X_1$ (5/14):
#     Subset 0: () gives pval = 0.55800 / val =  0.036
#     Non-significance detected.
#
#     Link ($X_2$ -2) --> $X_1$ (6/14):
#     Subset 0: () gives pval = 0.17900 / val =  0.049
#     Non-significance detected.
#
#     Link ($X_3$ -1) --> $X_1$ (7/14):
#     Subset 0: () gives pval = 0.19000 / val =  0.048
#     Non-significance detected.
#
#     Link ($X_3$ -2) --> $X_1$ (8/14):
#     Subset 0: () gives pval = 0.43900 / val =  0.039
#     Non-significance detected.
#
#     Link ($X_4$ -1) --> $X_1$ (9/14):
#     Subset 0: () gives pval = 0.98400 / val =  0.025
#     Non-significance detected.
#
#     Link ($X_4$ -2) --> $X_1$ (10/14):
#     Subset 0: () gives pval = 0.95400 / val =  0.027
#     Non-significance detected.
#
#     Link ($X_5$ -1) --> $X_1$ (11/14):
#     Subset 0: () gives pval = 0.43600 / val =  0.039
#     Non-significance detected.
#
#     Link ($X_5$ -2) --> $X_1$ (12/14):
#     Subset 0: () gives pval = 0.59800 / val =  0.036
#     Non-significance detected.
#
#     Link ($X_6$ -1) --> $X_1$ (13/14):
#     Subset 0: () gives pval = 0.86100 / val =  0.030
#     Non-significance detected.
#
#     Link ($X_6$ -2) --> $X_1$ (14/14):
#     Subset 0: () gives pval = 0.16900 / val =  0.049
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_1$ has 0 link(s):
#
# Algorithm converged for variable $X_1$
#
# ## Variable $X_2$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_0$ -1) --> $X_2$ (1/14):
#     Subset 0: () gives pval = 0.35700 / val =  0.042
#     Non-significance detected.
#
#     Link ($X_0$ -2) --> $X_2$ (2/14):
#     Subset 0: () gives pval = 0.14600 / val =  0.051
#     Non-significance detected.
#
#     Link ($X_1$ -1) --> $X_2$ (3/14):
#     Subset 0: () gives pval = 0.00000 / val =  0.693
#     No conditions of dimension 0 left.
#
#     Link ($X_1$ -2) --> $X_2$ (4/14):
#     Subset 0: () gives pval = 0.37500 / val =  0.041
#     Non-significance detected.
#
#     Link ($X_2$ -1) --> $X_2$ (5/14):
#     Subset 0: () gives pval = 0.68800 / val =  0.034
#     Non-significance detected.
#
#     Link ($X_2$ -2) --> $X_2$ (6/14):
#     Subset 0: () gives pval = 0.24100 / val =  0.046
#     Non-significance detected.
#
#     Link ($X_3$ -1) --> $X_2$ (7/14):
#     Subset 0: () gives pval = 0.73300 / val =  0.033
#     Non-significance detected.
#
#     Link ($X_3$ -2) --> $X_2$ (8/14):
#     Subset 0: () gives pval = 0.89800 / val =  0.029
#     Non-significance detected.
#
#     Link ($X_4$ -1) --> $X_2$ (9/14):
#     Subset 0: () gives pval = 0.88300 / val =  0.029
#     Non-significance detected.
#
#     Link ($X_4$ -2) --> $X_2$ (10/14):
#     Subset 0: () gives pval = 0.86100 / val =  0.030
#     Non-significance detected.
#
#     Link ($X_5$ -1) --> $X_2$ (11/14):
#     Subset 0: () gives pval = 0.12500 / val =  0.052
#     Non-significance detected.
#
#     Link ($X_5$ -2) --> $X_2$ (12/14):
#     Subset 0: () gives pval = 0.42900 / val =  0.040
#     Non-significance detected.
#
#     Link ($X_6$ -1) --> $X_2$ (13/14):
#     Subset 0: () gives pval = 0.45400 / val =  0.039
#     Non-significance detected.
#
#     Link ($X_6$ -2) --> $X_2$ (14/14):
#     Subset 0: () gives pval = 0.85400 / val =  0.030
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_2$ has 1 link(s):
#         ($X_1$ -1): max_pval = 0.00000, min_val =  0.693
#
# Algorithm converged for variable $X_2$
#
# ## Variable $X_3$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_0$ -1) --> $X_3$ (1/14):
#     Subset 0: () gives pval = 0.00000 / val =  0.437
#     No conditions of dimension 0 left.
#
#     Link ($X_0$ -2) --> $X_3$ (2/14):
#     Subset 0: () gives pval = 0.00000 / val =  0.367
#     No conditions of dimension 0 left.
#
#     Link ($X_1$ -1) --> $X_3$ (3/14):
#     Subset 0: () gives pval = 0.70100 / val =  0.033
#     Non-significance detected.
#
#     Link ($X_1$ -2) --> $X_3$ (4/14):
#     Subset 0: () gives pval = 0.25600 / val =  0.045
#     Non-significance detected.
#
#     Link ($X_2$ -1) --> $X_3$ (5/14):
#     Subset 0: () gives pval = 0.54600 / val =  0.037
#     Non-significance detected.
#
#     Link ($X_2$ -2) --> $X_3$ (6/14):
#     Subset 0: () gives pval = 0.00000 / val =  0.529
#     No conditions of dimension 0 left.
#
#     Link ($X_3$ -1) --> $X_3$ (7/14):
#     Subset 0: () gives pval = 0.00000 / val =  0.748
#     No conditions of dimension 0 left.
#
#     Link ($X_3$ -2) --> $X_3$ (8/14):
#     Subset 0: () gives pval = 0.00000 / val =  0.571
#     No conditions of dimension 0 left.
#
#     Link ($X_4$ -1) --> $X_3$ (9/14):
#     Subset 0: () gives pval = 0.00200 / val =  0.077
#     No conditions of dimension 0 left.
#
#     Link ($X_4$ -2) --> $X_3$ (10/14):
#     Subset 0: () gives pval = 0.00700 / val =  0.075
#     No conditions of dimension 0 left.
#
#     Link ($X_5$ -1) --> $X_3$ (11/14):
#     Subset 0: () gives pval = 0.14800 / val =  0.050
#     Non-significance detected.
#
#     Link ($X_5$ -2) --> $X_3$ (12/14):
#     Subset 0: () gives pval = 0.69100 / val =  0.033
#     Non-significance detected.
#
#     Link ($X_6$ -1) --> $X_3$ (13/14):
#     Subset 0: () gives pval = 0.42700 / val =  0.040
#     Non-significance detected.
#
#     Link ($X_6$ -2) --> $X_3$ (14/14):
#     Subset 0: () gives pval = 0.40000 / val =  0.040
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_3$ has 7 link(s):
#         ($X_3$ -1): max_pval = 0.00000, min_val =  0.748
#         ($X_3$ -2): max_pval = 0.00000, min_val =  0.571
#         ($X_2$ -2): max_pval = 0.00000, min_val =  0.529
#         ($X_0$ -1): max_pval = 0.00000, min_val =  0.437
#         ($X_0$ -2): max_pval = 0.00000, min_val =  0.367
#         ($X_4$ -1): max_pval = 0.00200, min_val =  0.077
#         ($X_4$ -2): max_pval = 0.00700, min_val =  0.075
#
# Testing condition sets of dimension 1:
#
#     Link ($X_3$ -1) --> $X_3$ (1/7):
#     Subset 0: ($X_3$ -2)  gives pval = 0.00000 / val =  0.515
#     No conditions of dimension 1 left.
#
#     Link ($X_3$ -2) --> $X_3$ (2/7):
#     Subset 0: ($X_3$ -1)  gives pval = 0.00800 / val =  0.074
#     No conditions of dimension 1 left.
#
#     Link ($X_2$ -2) --> $X_3$ (3/7):
#     Subset 0: ($X_3$ -1)  gives pval = 0.00000 / val =  0.877
#     No conditions of dimension 1 left.
#
#     Link ($X_0$ -1) --> $X_3$ (4/7):
#     Subset 0: ($X_3$ -1)  gives pval = 0.00500 / val =  0.077
#     No conditions of dimension 1 left.
#
#     Link ($X_0$ -2) --> $X_3$ (5/7):
#     Subset 0: ($X_3$ -1)  gives pval = 0.00200 / val =  0.078
#     No conditions of dimension 1 left.
#
#     Link ($X_4$ -1) --> $X_3$ (6/7):
#     Subset 0: ($X_3$ -1)  gives pval = 0.37000 / val =  0.041
#     Non-significance detected.
#
#     Link ($X_4$ -2) --> $X_3$ (7/7):
#     Subset 0: ($X_3$ -1)  gives pval = 0.51800 / val =  0.037
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_3$ has 5 link(s):
#         ($X_2$ -2): max_pval = 0.00000, min_val =  0.529
#         ($X_3$ -1): max_pval = 0.00000, min_val =  0.515
#         ($X_0$ -2): max_pval = 0.00200, min_val =  0.078
#         ($X_0$ -1): max_pval = 0.00500, min_val =  0.077
#         ($X_3$ -2): max_pval = 0.00800, min_val =  0.074
#
# Testing condition sets of dimension 2:
#
#     Link ($X_2$ -2) --> $X_3$ (1/5):
#     Subset 0: ($X_3$ -1) ($X_0$ -2)  gives pval = 0.00000 / val =  0.873
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_3$ -1) --> $X_3$ (2/5):
#     Subset 0: ($X_2$ -2) ($X_0$ -2)  gives pval = 0.00000 / val =  0.859
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_0$ -2) --> $X_3$ (3/5):
#     Subset 0: ($X_2$ -2) ($X_3$ -1)  gives pval = 0.52500 / val =  0.037
#     Non-significance detected.
#
#     Link ($X_0$ -1) --> $X_3$ (4/5):
#     Subset 0: ($X_2$ -2) ($X_3$ -1)  gives pval = 0.78500 / val =  0.032
#     Non-significance detected.
#
#     Link ($X_3$ -2) --> $X_3$ (5/5):
#     Subset 0: ($X_2$ -2) ($X_3$ -1)  gives pval = 0.47100 / val =  0.038
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_3$ has 2 link(s):
#         ($X_2$ -2): max_pval = 0.00000, min_val =  0.529
#         ($X_3$ -1): max_pval = 0.00000, min_val =  0.515
#
# Algorithm converged for variable $X_3$
#
# ## Variable $X_4$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_0$ -1) --> $X_4$ (1/14):
#     Subset 0: () gives pval = 0.00200 / val =  0.079
#     No conditions of dimension 0 left.
#
#     Link ($X_0$ -2) --> $X_4$ (2/14):
#     Subset 0: () gives pval = 0.00600 / val =  0.076
#     No conditions of dimension 0 left.
#
#     Link ($X_1$ -1) --> $X_4$ (3/14):
#     Subset 0: () gives pval = 0.98400 / val =  0.025
#     Non-significance detected.
#
#     Link ($X_1$ -2) --> $X_4$ (4/14):
#     Subset 0: () gives pval = 0.94200 / val =  0.028
#     Non-significance detected.
#
#     Link ($X_2$ -1) --> $X_4$ (5/14):
#     Subset 0: () gives pval = 0.90200 / val =  0.029
#     Non-significance detected.
#
#     Link ($X_2$ -2) --> $X_4$ (6/14):
#     Subset 0: () gives pval = 0.82900 / val =  0.030
#     Non-significance detected.
#
#     Link ($X_3$ -1) --> $X_4$ (7/14):
#     Subset 0: () gives pval = 0.00200 / val =  0.078
#     No conditions of dimension 0 left.
#
#     Link ($X_3$ -2) --> $X_4$ (8/14):
#     Subset 0: () gives pval = 0.00700 / val =  0.075
#     No conditions of dimension 0 left.
#
#     Link ($X_4$ -1) --> $X_4$ (9/14):
#     Subset 0: () gives pval = 0.00000 / val =  0.984
#     No conditions of dimension 0 left.
#
#     Link ($X_4$ -2) --> $X_4$ (10/14):
#     Subset 0: () gives pval = 0.00000 / val =  1.000
#     No conditions of dimension 0 left.
#
#     Link ($X_5$ -1) --> $X_4$ (11/14):
#     Subset 0: () gives pval = 0.01200 / val =  0.072
#     No conditions of dimension 0 left.
#
#     Link ($X_5$ -2) --> $X_4$ (12/14):
#     Subset 0: () gives pval = 0.02800 / val =  0.063
#     No conditions of dimension 0 left.
#
#     Link ($X_6$ -1) --> $X_4$ (13/14):
#     Subset 0: () gives pval = 0.82600 / val =  0.031
#     Non-significance detected.
#
#     Link ($X_6$ -2) --> $X_4$ (14/14):
#     Subset 0: () gives pval = 0.76500 / val =  0.032
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_4$ has 8 link(s):
#         ($X_4$ -2): max_pval = 0.00000, min_val =  1.000
#         ($X_4$ -1): max_pval = 0.00000, min_val =  0.984
#         ($X_0$ -1): max_pval = 0.00200, min_val =  0.079
#         ($X_3$ -1): max_pval = 0.00200, min_val =  0.078
#         ($X_0$ -2): max_pval = 0.00600, min_val =  0.076
#         ($X_3$ -2): max_pval = 0.00700, min_val =  0.075
#         ($X_5$ -1): max_pval = 0.01200, min_val =  0.072
#         ($X_5$ -2): max_pval = 0.02800, min_val =  0.063
#
# Testing condition sets of dimension 1:
#
#     Link ($X_4$ -2) --> $X_4$ (1/8):
#     Subset 0: ($X_4$ -1)  gives pval = 0.00000 / val =  0.995
#     No conditions of dimension 1 left.
#
#     Link ($X_4$ -1) --> $X_4$ (2/8):
#     Subset 0: ($X_4$ -2)  gives pval = 0.04400 / val =  0.060
#     No conditions of dimension 1 left.
#
#     Link ($X_0$ -1) --> $X_4$ (3/8):
#     Subset 0: ($X_4$ -2)  gives pval = 0.00000 / val =  0.564
#     No conditions of dimension 1 left.
#
#     Link ($X_3$ -1) --> $X_4$ (4/8):
#     Subset 0: ($X_4$ -2)  gives pval = 0.00000 / val =  0.242
#     No conditions of dimension 1 left.
#
#     Link ($X_0$ -2) --> $X_4$ (5/8):
#     Subset 0: ($X_4$ -2)  gives pval = 0.00000 / val =  0.394
#     No conditions of dimension 1 left.
#
#     Link ($X_3$ -2) --> $X_4$ (6/8):
#     Subset 0: ($X_4$ -2)  gives pval = 0.00000 / val =  0.413
#     No conditions of dimension 1 left.
#
#     Link ($X_5$ -1) --> $X_4$ (7/8):
#     Subset 0: ($X_4$ -2)  gives pval = 0.83400 / val =  0.030
#     Non-significance detected.
#
#     Link ($X_5$ -2) --> $X_4$ (8/8):
#     Subset 0: ($X_4$ -2)  gives pval = 0.00000 / val =  0.635
#     No conditions of dimension 1 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_4$ has 7 link(s):
#         ($X_4$ -2): max_pval = 0.00000, min_val =  0.995
#         ($X_0$ -1): max_pval = 0.00200, min_val =  0.079
#         ($X_3$ -1): max_pval = 0.00200, min_val =  0.078
#         ($X_0$ -2): max_pval = 0.00600, min_val =  0.076
#         ($X_3$ -2): max_pval = 0.00700, min_val =  0.075
#         ($X_5$ -2): max_pval = 0.02800, min_val =  0.063
#         ($X_4$ -1): max_pval = 0.04400, min_val =  0.060
#
# Testing condition sets of dimension 2:
#
#     Link ($X_4$ -2) --> $X_4$ (1/7):
#     Subset 0: ($X_0$ -1) ($X_3$ -1)  gives pval = 0.00000 / val =  1.000
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_0$ -1) --> $X_4$ (2/7):
#     Subset 0: ($X_4$ -2) ($X_3$ -1)  gives pval = 0.00000 / val =  0.499
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_3$ -1) --> $X_4$ (3/7):
#     Subset 0: ($X_4$ -2) ($X_0$ -1)  gives pval = 0.00000 / val =  0.103
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_0$ -2) --> $X_4$ (4/7):
#     Subset 0: ($X_4$ -2) ($X_0$ -1)  gives pval = 0.00200 / val =  0.077
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_3$ -2) --> $X_4$ (5/7):
#     Subset 0: ($X_4$ -2) ($X_0$ -1)  gives pval = 0.00100 / val =  0.088
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_5$ -2) --> $X_4$ (6/7):
#     Subset 0: ($X_4$ -2) ($X_0$ -1)  gives pval = 0.00000 / val =  0.907
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_4$ -1) --> $X_4$ (7/7):
#     Subset 0: ($X_4$ -2) ($X_0$ -1)  gives pval = 0.10000 / val =  0.054
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_4$ has 6 link(s):
#         ($X_4$ -2): max_pval = 0.00000, min_val =  0.995
#         ($X_0$ -1): max_pval = 0.00200, min_val =  0.079
#         ($X_3$ -1): max_pval = 0.00200, min_val =  0.078
#         ($X_0$ -2): max_pval = 0.00600, min_val =  0.076
#         ($X_3$ -2): max_pval = 0.00700, min_val =  0.075
#         ($X_5$ -2): max_pval = 0.02800, min_val =  0.063
#
# Testing condition sets of dimension 3:
#
#     Link ($X_4$ -2) --> $X_4$ (1/6):
#     Subset 0: ($X_0$ -1) ($X_3$ -1) ($X_0$ -2)  gives pval = 0.00000 / val =  1.000
#     Still subsets of dimension 3 left, but q_max = 1 reached.
#
#     Link ($X_0$ -1) --> $X_4$ (2/6):
#     Subset 0: ($X_4$ -2) ($X_3$ -1) ($X_0$ -2)  gives pval = 0.00000 / val =  0.385
#     Still subsets of dimension 3 left, but q_max = 1 reached.
#
#     Link ($X_3$ -1) --> $X_4$ (3/6):
#     Subset 0: ($X_4$ -2) ($X_0$ -1) ($X_0$ -2)  gives pval = 0.00000 / val =  0.103
#     Still subsets of dimension 3 left, but q_max = 1 reached.
#
#     Link ($X_0$ -2) --> $X_4$ (4/6):
#     Subset 0: ($X_4$ -2) ($X_0$ -1) ($X_3$ -1)  gives pval = 0.00600 / val =  0.076
#     Still subsets of dimension 3 left, but q_max = 1 reached.
#
#     Link ($X_3$ -2) --> $X_4$ (5/6):
#     Subset 0: ($X_4$ -2) ($X_0$ -1) ($X_3$ -1)  gives pval = 0.00100 / val =  0.090
#     Still subsets of dimension 3 left, but q_max = 1 reached.
#
#     Link ($X_5$ -2) --> $X_4$ (6/6):
#     Subset 0: ($X_4$ -2) ($X_0$ -1) ($X_3$ -1)  gives pval = 0.00000 / val =  0.908
#     Still subsets of dimension 3 left, but q_max = 1 reached.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_4$ has 6 link(s):
#         ($X_4$ -2): max_pval = 0.00000, min_val =  0.995
#         ($X_0$ -1): max_pval = 0.00200, min_val =  0.079
#         ($X_3$ -1): max_pval = 0.00200, min_val =  0.078
#         ($X_0$ -2): max_pval = 0.00600, min_val =  0.076
#         ($X_3$ -2): max_pval = 0.00700, min_val =  0.075
#         ($X_5$ -2): max_pval = 0.02800, min_val =  0.063
#
# Testing condition sets of dimension 4:
#
#     Link ($X_4$ -2) --> $X_4$ (1/6):
#     Subset 0: ($X_0$ -1) ($X_3$ -1) ($X_0$ -2) ($X_3$ -2)  gives pval = 0.00000 / val =  1.000
#     Still subsets of dimension 4 left, but q_max = 1 reached.
#
#     Link ($X_0$ -1) --> $X_4$ (2/6):
#     Subset 0: ($X_4$ -2) ($X_3$ -1) ($X_0$ -2) ($X_3$ -2)  gives pval = 0.00000 / val =  0.342
#     Still subsets of dimension 4 left, but q_max = 1 reached.
#
#     Link ($X_3$ -1) --> $X_4$ (3/6):
#     Subset 0: ($X_4$ -2) ($X_0$ -1) ($X_0$ -2) ($X_3$ -2)  gives pval = 0.00100 / val =  0.085
#     Still subsets of dimension 4 left, but q_max = 1 reached.
#
#     Link ($X_0$ -2) --> $X_4$ (4/6):
#     Subset 0: ($X_4$ -2) ($X_0$ -1) ($X_3$ -1) ($X_3$ -2)  gives pval = 0.00200 / val =  0.079
#     Still subsets of dimension 4 left, but q_max = 1 reached.
#
#     Link ($X_3$ -2) --> $X_4$ (5/6):
#     Subset 0: ($X_4$ -2) ($X_0$ -1) ($X_3$ -1) ($X_0$ -2)  gives pval = 0.00100 / val =  0.091
#     Still subsets of dimension 4 left, but q_max = 1 reached.
#
#     Link ($X_5$ -2) --> $X_4$ (6/6):
#     Subset 0: ($X_4$ -2) ($X_0$ -1) ($X_3$ -1) ($X_0$ -2)  gives pval = 0.00000 / val =  0.903
#     Still subsets of dimension 4 left, but q_max = 1 reached.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_4$ has 6 link(s):
#         ($X_4$ -2): max_pval = 0.00000, min_val =  0.995
#         ($X_0$ -1): max_pval = 0.00200, min_val =  0.079
#         ($X_3$ -1): max_pval = 0.00200, min_val =  0.078
#         ($X_0$ -2): max_pval = 0.00600, min_val =  0.076
#         ($X_3$ -2): max_pval = 0.00700, min_val =  0.075
#         ($X_5$ -2): max_pval = 0.02800, min_val =  0.063
#
# Testing condition sets of dimension 5:
#
#     Link ($X_4$ -2) --> $X_4$ (1/6):
#     Subset 0: ($X_0$ -1) ($X_3$ -1) ($X_0$ -2) ($X_3$ -2) ($X_5$ -2)  gives pval = 0.00000 / val =  1.000
#     Still subsets of dimension 5 left, but q_max = 1 reached.
#
#     Link ($X_0$ -1) --> $X_4$ (2/6):
#     Subset 0: ($X_4$ -2) ($X_3$ -1) ($X_0$ -2) ($X_3$ -2) ($X_5$ -2)  gives pval = 0.00000 / val =  0.782
#     Still subsets of dimension 5 left, but q_max = 1 reached.
#
#     Link ($X_3$ -1) --> $X_4$ (3/6):
#     Subset 0: ($X_4$ -2) ($X_0$ -1) ($X_0$ -2) ($X_3$ -2) ($X_5$ -2)  gives pval = 0.48800 / val =  0.038
#     Non-significance detected.
#
#     Link ($X_0$ -2) --> $X_4$ (4/6):
#     Subset 0: ($X_4$ -2) ($X_0$ -1) ($X_3$ -1) ($X_3$ -2) ($X_5$ -2)  gives pval = 0.54800 / val =  0.037
#     Non-significance detected.
#
#     Link ($X_3$ -2) --> $X_4$ (5/6):
#     Subset 0: ($X_4$ -2) ($X_0$ -1) ($X_3$ -1) ($X_0$ -2) ($X_5$ -2)  gives pval = 0.26800 / val =  0.045
#     Non-significance detected.
#
#     Link ($X_5$ -2) --> $X_4$ (6/6):
#     Subset 0: ($X_4$ -2) ($X_0$ -1) ($X_3$ -1) ($X_0$ -2) ($X_3$ -2)  gives pval = 0.00000 / val =  0.889
#     Still subsets of dimension 5 left, but q_max = 1 reached.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_4$ has 3 link(s):
#         ($X_4$ -2): max_pval = 0.00000, min_val =  0.995
#         ($X_0$ -1): max_pval = 0.00200, min_val =  0.079
#         ($X_5$ -2): max_pval = 0.02800, min_val =  0.063
#
# Algorithm converged for variable $X_4$
#
# ## Variable $X_5$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_0$ -1) --> $X_5$ (1/14):
#     Subset 0: () gives pval = 0.99500 / val =  0.024
#     Non-significance detected.
#
#     Link ($X_0$ -2) --> $X_5$ (2/14):
#     Subset 0: () gives pval = 0.66300 / val =  0.034
#     Non-significance detected.
#
#     Link ($X_1$ -1) --> $X_5$ (3/14):
#     Subset 0: () gives pval = 0.20400 / val =  0.048
#     Non-significance detected.
#
#     Link ($X_1$ -2) --> $X_5$ (4/14):
#     Subset 0: () gives pval = 0.03700 / val =  0.061
#     No conditions of dimension 0 left.
#
#     Link ($X_2$ -1) --> $X_5$ (5/14):
#     Subset 0: () gives pval = 0.20300 / val =  0.048
#     Non-significance detected.
#
#     Link ($X_2$ -2) --> $X_5$ (6/14):
#     Subset 0: () gives pval = 0.78300 / val =  0.032
#     Non-significance detected.
#
#     Link ($X_3$ -1) --> $X_5$ (7/14):
#     Subset 0: () gives pval = 0.77100 / val =  0.032
#     Non-significance detected.
#
#     Link ($X_3$ -2) --> $X_5$ (8/14):
#     Subset 0: () gives pval = 0.56100 / val =  0.036
#     Non-significance detected.
#
#     Link ($X_4$ -1) --> $X_5$ (9/14):
#     Subset 0: () gives pval = 0.00800 / val =  0.074
#     No conditions of dimension 0 left.
#
#     Link ($X_4$ -2) --> $X_5$ (10/14):
#     Subset 0: () gives pval = 0.02100 / val =  0.067
#     No conditions of dimension 0 left.
#
#     Link ($X_5$ -1) --> $X_5$ (11/14):
#     Subset 0: () gives pval = 0.68700 / val =  0.034
#     Non-significance detected.
#
#     Link ($X_5$ -2) --> $X_5$ (12/14):
#     Subset 0: () gives pval = 0.62800 / val =  0.035
#     Non-significance detected.
#
#     Link ($X_6$ -1) --> $X_5$ (13/14):
#     Subset 0: () gives pval = 0.01200 / val =  0.072
#     No conditions of dimension 0 left.
#
#     Link ($X_6$ -2) --> $X_5$ (14/14):
#     Subset 0: () gives pval = 0.15600 / val =  0.050
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_5$ has 4 link(s):
#         ($X_4$ -1): max_pval = 0.00800, min_val =  0.074
#         ($X_6$ -1): max_pval = 0.01200, min_val =  0.072
#         ($X_4$ -2): max_pval = 0.02100, min_val =  0.067
#         ($X_1$ -2): max_pval = 0.03700, min_val =  0.061
#
# Testing condition sets of dimension 1:
#
#     Link ($X_4$ -1) --> $X_5$ (1/4):
#     Subset 0: ($X_6$ -1)  gives pval = 0.00900 / val =  0.073
#     No conditions of dimension 1 left.
#
#     Link ($X_6$ -1) --> $X_5$ (2/4):
#     Subset 0: ($X_4$ -1)  gives pval = 0.01500 / val =  0.071
#     No conditions of dimension 1 left.
#
#     Link ($X_4$ -2) --> $X_5$ (3/4):
#     Subset 0: ($X_4$ -1)  gives pval = 0.09400 / val =  0.055
#     Non-significance detected.
#
#     Link ($X_1$ -2) --> $X_5$ (4/4):
#     Subset 0: ($X_4$ -1)  gives pval = 0.03100 / val =  0.062
#     No conditions of dimension 1 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_5$ has 3 link(s):
#         ($X_4$ -1): max_pval = 0.00900, min_val =  0.073
#         ($X_6$ -1): max_pval = 0.01500, min_val =  0.071
#         ($X_1$ -2): max_pval = 0.03700, min_val =  0.061
#
# Testing condition sets of dimension 2:
#
#     Link ($X_4$ -1) --> $X_5$ (1/3):
#     Subset 0: ($X_6$ -1) ($X_1$ -2)  gives pval = 0.00800 / val =  0.075
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_6$ -1) --> $X_5$ (2/3):
#     Subset 0: ($X_4$ -1) ($X_1$ -2)  gives pval = 0.01600 / val =  0.070
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Link ($X_1$ -2) --> $X_5$ (3/3):
#     Subset 0: ($X_4$ -1) ($X_6$ -1)  gives pval = 0.03700 / val =  0.061
#     Still subsets of dimension 2 left, but q_max = 1 reached.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_5$ has 3 link(s):
#         ($X_4$ -1): max_pval = 0.00900, min_val =  0.073
#         ($X_6$ -1): max_pval = 0.01600, min_val =  0.070
#         ($X_1$ -2): max_pval = 0.03700, min_val =  0.061
#
# Algorithm converged for variable $X_5$
#
# ## Variable $X_6$
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link ($X_0$ -1) --> $X_6$ (1/14):
#     Subset 0: () gives pval = 0.68000 / val =  0.034
#     Non-significance detected.
#
#     Link ($X_0$ -2) --> $X_6$ (2/14):
#     Subset 0: () gives pval = 0.54700 / val =  0.037
#     Non-significance detected.
#
#     Link ($X_1$ -1) --> $X_6$ (3/14):
#     Subset 0: () gives pval = 0.07900 / val =  0.056
#     Non-significance detected.
#
#     Link ($X_1$ -2) --> $X_6$ (4/14):
#     Subset 0: () gives pval = 0.13500 / val =  0.051
#     Non-significance detected.
#
#     Link ($X_2$ -1) --> $X_6$ (5/14):
#     Subset 0: () gives pval = 0.39100 / val =  0.041
#     Non-significance detected.
#
#     Link ($X_2$ -2) --> $X_6$ (6/14):
#     Subset 0: () gives pval = 0.42300 / val =  0.040
#     Non-significance detected.
#
#     Link ($X_3$ -1) --> $X_6$ (7/14):
#     Subset 0: () gives pval = 0.52500 / val =  0.037
#     Non-significance detected.
#
#     Link ($X_3$ -2) --> $X_6$ (8/14):
#     Subset 0: () gives pval = 0.55900 / val =  0.036
#     Non-significance detected.
#
#     Link ($X_4$ -1) --> $X_6$ (9/14):
#     Subset 0: () gives pval = 0.82800 / val =  0.030
#     Non-significance detected.
#
#     Link ($X_4$ -2) --> $X_6$ (10/14):
#     Subset 0: () gives pval = 0.77400 / val =  0.032
#     Non-significance detected.
#
#     Link ($X_5$ -1) --> $X_6$ (11/14):
#     Subset 0: () gives pval = 0.62100 / val =  0.035
#     Non-significance detected.
#
#     Link ($X_5$ -2) --> $X_6$ (12/14):
#     Subset 0: () gives pval = 0.27600 / val =  0.044
#     Non-significance detected.
#
#     Link ($X_6$ -1) --> $X_6$ (13/14):
#     Subset 0: () gives pval = 0.58200 / val =  0.036
#     Non-significance detected.
#
#     Link ($X_6$ -2) --> $X_6$ (14/14):
#     Subset 0: () gives pval = 0.70300 / val =  0.033
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable $X_6$ has 0 link(s):
#
# Algorithm converged for variable $X_6$
#
# ## Resulting lagged parent (super)sets:
#
#     Variable $X_0$ has 2 link(s):
#         ($X_3$ -2): max_pval = 0.00000, min_val =  0.987
#         ($X_1$ -1): max_pval = 0.00100, min_val =  0.085
#
#     Variable $X_1$ has 0 link(s):
#
#     Variable $X_2$ has 1 link(s):
#         ($X_1$ -1): max_pval = 0.00000, min_val =  0.693
#
#     Variable $X_3$ has 2 link(s):
#         ($X_2$ -2): max_pval = 0.00000, min_val =  0.529
#         ($X_3$ -1): max_pval = 0.00000, min_val =  0.748
#
#     Variable $X_4$ has 3 link(s):
#         ($X_4$ -2): max_pval = 0.00000, min_val =  1.000
#         ($X_0$ -1): max_pval = 0.00200, min_val =  0.079
#         ($X_5$ -2): max_pval = 0.02800, min_val =  0.063
#
#     Variable $X_5$ has 3 link(s):
#         ($X_4$ -1): max_pval = 0.00900, min_val =  0.073
#         ($X_6$ -1): max_pval = 0.01600, min_val =  0.070
#         ($X_1$ -2): max_pval = 0.03700, min_val =  0.061
#
#     Variable $X_6$ has 0 link(s):
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = gp_dc
# tau_min = 1
# tau_max = 2
# max_conds_py = None
# max_conds_px = None
#
#         link ($X_0$ -1) --> $X_0$ (1/14):
#         with conds_y = [ ($X_3$ -2) ($X_1$ -1) ]
#         with conds_x = [ ($X_3$ -3) ($X_1$ -2) ]
#
#         link ($X_0$ -2) --> $X_0$ (2/14):
#         with conds_y = [ ($X_3$ -2) ($X_1$ -1) ]
#         with conds_x = [ ($X_3$ -4) ($X_1$ -3) ]
#
#         link ($X_1$ -1) --> $X_0$ (3/14):
#         with conds_y = [ ($X_3$ -2) ]
#         with conds_x = [ ]
#
#         link ($X_1$ -2) --> $X_0$ (4/14):
#         with conds_y = [ ($X_3$ -2) ($X_1$ -1) ]
#         with conds_x = [ ]
#
#         link ($X_2$ -1) --> $X_0$ (5/14):
#         with conds_y = [ ($X_3$ -2) ($X_1$ -1) ]
#         with conds_x = [ ($X_1$ -2) ]
#
#         link ($X_2$ -2) --> $X_0$ (6/14):
#         with conds_y = [ ($X_3$ -2) ($X_1$ -1) ]
#         with conds_x = [ ($X_1$ -3) ]
#
#         link ($X_3$ -1) --> $X_0$ (7/14):
#         with conds_y = [ ($X_3$ -2) ($X_1$ -1) ]
#         with conds_x = [ ($X_2$ -3) ($X_3$ -2) ]
#
#         link ($X_3$ -2) --> $X_0$ (8/14):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ($X_2$ -4) ($X_3$ -3) ]
#
#         link ($X_4$ -1) --> $X_0$ (9/14):
#         with conds_y = [ ($X_3$ -2) ($X_1$ -1) ]
#         with conds_x = [ ($X_4$ -3) ($X_0$ -2) ($X_5$ -3) ]
#
#         link ($X_4$ -2) --> $X_0$ (10/14):
#         with conds_y = [ ($X_3$ -2) ($X_1$ -1) ]
#         with conds_x = [ ($X_4$ -4) ($X_0$ -3) ($X_5$ -4) ]
#
#         link ($X_5$ -1) --> $X_0$ (11/14):
#         with conds_y = [ ($X_3$ -2) ($X_1$ -1) ]
#         with conds_x = [ ($X_4$ -2) ($X_6$ -2) ($X_1$ -3) ]
#
#         link ($X_5$ -2) --> $X_0$ (12/14):
#         with conds_y = [ ($X_3$ -2) ($X_1$ -1) ]
#         with conds_x = [ ($X_4$ -3) ($X_6$ -3) ($X_1$ -4) ]
#
#         link ($X_6$ -1) --> $X_0$ (13/14):
#         with conds_y = [ ($X_3$ -2) ($X_1$ -1) ]
#         with conds_x = [ ]
#
#         link ($X_6$ -2) --> $X_0$ (14/14):
#         with conds_y = [ ($X_3$ -2) ($X_1$ -1) ]
#         with conds_x = [ ]
#
#         link ($X_0$ -1) --> $X_1$ (1/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_3$ -3) ($X_1$ -2) ]
#
#         link ($X_0$ -2) --> $X_1$ (2/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_3$ -4) ($X_1$ -3) ]
#
#         link ($X_1$ -1) --> $X_1$ (3/14):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link ($X_1$ -2) --> $X_1$ (4/14):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link ($X_2$ -1) --> $X_1$ (5/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_1$ -2) ]
#
#         link ($X_2$ -2) --> $X_1$ (6/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_1$ -3) ]
#
#         link ($X_3$ -1) --> $X_1$ (7/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_2$ -3) ($X_3$ -2) ]
#
#         link ($X_3$ -2) --> $X_1$ (8/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_2$ -4) ($X_3$ -3) ]
#
#         link ($X_4$ -1) --> $X_1$ (9/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_4$ -3) ($X_0$ -2) ($X_5$ -3) ]
#
#         link ($X_4$ -2) --> $X_1$ (10/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_4$ -4) ($X_0$ -3) ($X_5$ -4) ]
#
#         link ($X_5$ -1) --> $X_1$ (11/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_4$ -2) ($X_6$ -2) ($X_1$ -3) ]
#
#         link ($X_5$ -2) --> $X_1$ (12/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_4$ -3) ($X_6$ -3) ($X_1$ -4) ]
#
#         link ($X_6$ -1) --> $X_1$ (13/14):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link ($X_6$ -2) --> $X_1$ (14/14):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link ($X_0$ -1) --> $X_2$ (1/14):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ($X_3$ -3) ($X_1$ -2) ]
#
#         link ($X_0$ -2) --> $X_2$ (2/14):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ($X_3$ -4) ($X_1$ -3) ]
#
#         link ($X_1$ -1) --> $X_2$ (3/14):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link ($X_1$ -2) --> $X_2$ (4/14):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ]
#
#         link ($X_2$ -1) --> $X_2$ (5/14):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ($X_1$ -2) ]
#
#         link ($X_2$ -2) --> $X_2$ (6/14):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ($X_1$ -3) ]
#
#         link ($X_3$ -1) --> $X_2$ (7/14):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ($X_2$ -3) ($X_3$ -2) ]
#
#         link ($X_3$ -2) --> $X_2$ (8/14):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ($X_2$ -4) ($X_3$ -3) ]
#
#         link ($X_4$ -1) --> $X_2$ (9/14):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ($X_4$ -3) ($X_0$ -2) ($X_5$ -3) ]
#
#         link ($X_4$ -2) --> $X_2$ (10/14):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ($X_4$ -4) ($X_0$ -3) ($X_5$ -4) ]
#
#         link ($X_5$ -1) --> $X_2$ (11/14):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ($X_4$ -2) ($X_6$ -2) ($X_1$ -3) ]
#
#         link ($X_5$ -2) --> $X_2$ (12/14):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ($X_4$ -3) ($X_6$ -3) ($X_1$ -4) ]
#
#         link ($X_6$ -1) --> $X_2$ (13/14):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ]
#
#         link ($X_6$ -2) --> $X_2$ (14/14):
#         with conds_y = [ ($X_1$ -1) ]
#         with conds_x = [ ]
#
#         link ($X_0$ -1) --> $X_3$ (1/14):
#         with conds_y = [ ($X_2$ -2) ($X_3$ -1) ]
#         with conds_x = [ ($X_3$ -3) ($X_1$ -2) ]
#
#         link ($X_0$ -2) --> $X_3$ (2/14):
#         with conds_y = [ ($X_2$ -2) ($X_3$ -1) ]
#         with conds_x = [ ($X_3$ -4) ($X_1$ -3) ]
#
#         link ($X_1$ -1) --> $X_3$ (3/14):
#         with conds_y = [ ($X_2$ -2) ($X_3$ -1) ]
#         with conds_x = [ ]
#
#         link ($X_1$ -2) --> $X_3$ (4/14):
#         with conds_y = [ ($X_2$ -2) ($X_3$ -1) ]
#         with conds_x = [ ]
#
#         link ($X_2$ -1) --> $X_3$ (5/14):
#         with conds_y = [ ($X_2$ -2) ($X_3$ -1) ]
#         with conds_x = [ ($X_1$ -2) ]
#
#         link ($X_2$ -2) --> $X_3$ (6/14):
#         with conds_y = [ ($X_3$ -1) ]
#         with conds_x = [ ($X_1$ -3) ]
#
#         link ($X_3$ -1) --> $X_3$ (7/14):
#         with conds_y = [ ($X_2$ -2) ]
#         with conds_x = [ ($X_2$ -3) ($X_3$ -2) ]
#
#         link ($X_3$ -2) --> $X_3$ (8/14):
#         with conds_y = [ ($X_2$ -2) ($X_3$ -1) ]
#         with conds_x = [ ($X_2$ -4) ($X_3$ -3) ]
#
#         link ($X_4$ -1) --> $X_3$ (9/14):
#         with conds_y = [ ($X_2$ -2) ($X_3$ -1) ]
#         with conds_x = [ ($X_4$ -3) ($X_0$ -2) ($X_5$ -3) ]
#
#         link ($X_4$ -2) --> $X_3$ (10/14):
#         with conds_y = [ ($X_2$ -2) ($X_3$ -1) ]
#         with conds_x = [ ($X_4$ -4) ($X_0$ -3) ($X_5$ -4) ]
#
#         link ($X_5$ -1) --> $X_3$ (11/14):
#         with conds_y = [ ($X_2$ -2) ($X_3$ -1) ]
#         with conds_x = [ ($X_4$ -2) ($X_6$ -2) ($X_1$ -3) ]
#
#         link ($X_5$ -2) --> $X_3$ (12/14):
#         with conds_y = [ ($X_2$ -2) ($X_3$ -1) ]
#         with conds_x = [ ($X_4$ -3) ($X_6$ -3) ($X_1$ -4) ]
#
#         link ($X_6$ -1) --> $X_3$ (13/14):
#         with conds_y = [ ($X_2$ -2) ($X_3$ -1) ]
#         with conds_x = [ ]
#
#         link ($X_6$ -2) --> $X_3$ (14/14):
#         with conds_y = [ ($X_2$ -2) ($X_3$ -1) ]
#         with conds_x = [ ]
#
#         link ($X_0$ -1) --> $X_4$ (1/14):
#         with conds_y = [ ($X_4$ -2) ($X_5$ -2) ]
#         with conds_x = [ ($X_3$ -3) ($X_1$ -2) ]
#
#         link ($X_0$ -2) --> $X_4$ (2/14):
#         with conds_y = [ ($X_4$ -2) ($X_0$ -1) ($X_5$ -2) ]
#         with conds_x = [ ($X_3$ -4) ($X_1$ -3) ]
#
#         link ($X_1$ -1) --> $X_4$ (3/14):
#         with conds_y = [ ($X_4$ -2) ($X_0$ -1) ($X_5$ -2) ]
#         with conds_x = [ ]
#
#         link ($X_1$ -2) --> $X_4$ (4/14):
#         with conds_y = [ ($X_4$ -2) ($X_0$ -1) ($X_5$ -2) ]
#         with conds_x = [ ]
#
#         link ($X_2$ -1) --> $X_4$ (5/14):
#         with conds_y = [ ($X_4$ -2) ($X_0$ -1) ($X_5$ -2) ]
#         with conds_x = [ ($X_1$ -2) ]
#
#         link ($X_2$ -2) --> $X_4$ (6/14):
#         with conds_y = [ ($X_4$ -2) ($X_0$ -1) ($X_5$ -2) ]
#         with conds_x = [ ($X_1$ -3) ]
#
#         link ($X_3$ -1) --> $X_4$ (7/14):
#         with conds_y = [ ($X_4$ -2) ($X_0$ -1) ($X_5$ -2) ]
#         with conds_x = [ ($X_2$ -3) ($X_3$ -2) ]
#
#         link ($X_3$ -2) --> $X_4$ (8/14):
#         with conds_y = [ ($X_4$ -2) ($X_0$ -1) ($X_5$ -2) ]
#         with conds_x = [ ($X_2$ -4) ($X_3$ -3) ]
#
#         link ($X_4$ -1) --> $X_4$ (9/14):
#         with conds_y = [ ($X_4$ -2) ($X_0$ -1) ($X_5$ -2) ]
#         with conds_x = [ ($X_4$ -3) ($X_0$ -2) ($X_5$ -3) ]
#
#         link ($X_4$ -2) --> $X_4$ (10/14):
#         with conds_y = [ ($X_0$ -1) ($X_5$ -2) ]
#         with conds_x = [ ($X_4$ -4) ($X_0$ -3) ($X_5$ -4) ]
#
#         link ($X_5$ -1) --> $X_4$ (11/14):
#         with conds_y = [ ($X_4$ -2) ($X_0$ -1) ($X_5$ -2) ]
#         with conds_x = [ ($X_4$ -2) ($X_6$ -2) ($X_1$ -3) ]
#
#         link ($X_5$ -2) --> $X_4$ (12/14):
#         with conds_y = [ ($X_4$ -2) ($X_0$ -1) ]
#         with conds_x = [ ($X_4$ -3) ($X_6$ -3) ($X_1$ -4) ]
#
#         link ($X_6$ -1) --> $X_4$ (13/14):
#         with conds_y = [ ($X_4$ -2) ($X_0$ -1) ($X_5$ -2) ]
#         with conds_x = [ ]
#
#         link ($X_6$ -2) --> $X_4$ (14/14):
#         with conds_y = [ ($X_4$ -2) ($X_0$ -1) ($X_5$ -2) ]
#         with conds_x = [ ]
#
#         link ($X_0$ -1) --> $X_5$ (1/14):
#         with conds_y = [ ($X_4$ -1) ($X_6$ -1) ($X_1$ -2) ]
#         with conds_x = [ ($X_3$ -3) ($X_1$ -2) ]
#
#         link ($X_0$ -2) --> $X_5$ (2/14):
#         with conds_y = [ ($X_4$ -1) ($X_6$ -1) ($X_1$ -2) ]
#         with conds_x = [ ($X_3$ -4) ($X_1$ -3) ]
#
#         link ($X_1$ -1) --> $X_5$ (3/14):
#         with conds_y = [ ($X_4$ -1) ($X_6$ -1) ($X_1$ -2) ]
#         with conds_x = [ ]
#
#         link ($X_1$ -2) --> $X_5$ (4/14):
#         with conds_y = [ ($X_4$ -1) ($X_6$ -1) ]
#         with conds_x = [ ]
#
#         link ($X_2$ -1) --> $X_5$ (5/14):
#         with conds_y = [ ($X_4$ -1) ($X_6$ -1) ($X_1$ -2) ]
#         with conds_x = [ ($X_1$ -2) ]
#
#         link ($X_2$ -2) --> $X_5$ (6/14):
#         with conds_y = [ ($X_4$ -1) ($X_6$ -1) ($X_1$ -2) ]
#         with conds_x = [ ($X_1$ -3) ]
#
#         link ($X_3$ -1) --> $X_5$ (7/14):
#         with conds_y = [ ($X_4$ -1) ($X_6$ -1) ($X_1$ -2) ]
#         with conds_x = [ ($X_2$ -3) ($X_3$ -2) ]
#
#         link ($X_3$ -2) --> $X_5$ (8/14):
#         with conds_y = [ ($X_4$ -1) ($X_6$ -1) ($X_1$ -2) ]
#         with conds_x = [ ($X_2$ -4) ($X_3$ -3) ]
#
#         link ($X_4$ -1) --> $X_5$ (9/14):
#         with conds_y = [ ($X_6$ -1) ($X_1$ -2) ]
#         with conds_x = [ ($X_4$ -3) ($X_0$ -2) ($X_5$ -3) ]
#
#         link ($X_4$ -2) --> $X_5$ (10/14):
#         with conds_y = [ ($X_4$ -1) ($X_6$ -1) ($X_1$ -2) ]
#         with conds_x = [ ($X_4$ -4) ($X_0$ -3) ($X_5$ -4) ]
#
#         link ($X_5$ -1) --> $X_5$ (11/14):
#         with conds_y = [ ($X_4$ -1) ($X_6$ -1) ($X_1$ -2) ]
#         with conds_x = [ ($X_4$ -2) ($X_6$ -2) ($X_1$ -3) ]
#
#         link ($X_5$ -2) --> $X_5$ (12/14):
#         with conds_y = [ ($X_4$ -1) ($X_6$ -1) ($X_1$ -2) ]
#         with conds_x = [ ($X_4$ -3) ($X_6$ -3) ($X_1$ -4) ]
#
#         link ($X_6$ -1) --> $X_5$ (13/14):
#         with conds_y = [ ($X_4$ -1) ($X_1$ -2) ]
#         with conds_x = [ ]
#
#         link ($X_6$ -2) --> $X_5$ (14/14):
#         with conds_y = [ ($X_4$ -1) ($X_6$ -1) ($X_1$ -2) ]
#         with conds_x = [ ]
#
#         link ($X_0$ -1) --> $X_6$ (1/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_3$ -3) ($X_1$ -2) ]
#
#         link ($X_0$ -2) --> $X_6$ (2/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_3$ -4) ($X_1$ -3) ]
#
#         link ($X_1$ -1) --> $X_6$ (3/14):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link ($X_1$ -2) --> $X_6$ (4/14):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link ($X_2$ -1) --> $X_6$ (5/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_1$ -2) ]
#
#         link ($X_2$ -2) --> $X_6$ (6/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_1$ -3) ]
#
#         link ($X_3$ -1) --> $X_6$ (7/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_2$ -3) ($X_3$ -2) ]
#
#         link ($X_3$ -2) --> $X_6$ (8/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_2$ -4) ($X_3$ -3) ]
#
#         link ($X_4$ -1) --> $X_6$ (9/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_4$ -3) ($X_0$ -2) ($X_5$ -3) ]
#
#         link ($X_4$ -2) --> $X_6$ (10/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_4$ -4) ($X_0$ -3) ($X_5$ -4) ]
#
#         link ($X_5$ -1) --> $X_6$ (11/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_4$ -2) ($X_6$ -2) ($X_1$ -3) ]
#
#         link ($X_5$ -2) --> $X_6$ (12/14):
#         with conds_y = [ ]
#         with conds_x = [ ($X_4$ -3) ($X_6$ -3) ($X_1$ -4) ]
#
#         link ($X_6$ -1) --> $X_6$ (13/14):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link ($X_6$ -2) --> $X_6$ (14/14):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
# ## Significant links at alpha = 0.05:
#
#     Variable $X_0$ has 2 link(s):
#         ($X_3$ -2): pval = 0.00000 | val =  0.947
#         ($X_1$ -1): pval = 0.00000 | val =  0.887
#
#     Variable $X_1$ has 0 link(s):
#
#     Variable $X_2$ has 1 link(s):
#         ($X_1$ -1): pval = 0.00000 | val =  0.693
#
#     Variable $X_3$ has 2 link(s):
#         ($X_2$ -2): pval = 0.00000 | val =  0.818
#         ($X_3$ -1): pval = 0.00000 | val =  0.533
#
#     Variable $X_4$ has 5 link(s):
#         ($X_5$ -2): pval = 0.00000 | val =  0.864
#         ($X_4$ -2): pval = 0.00000 | val =  0.754
#         ($X_4$ -1): pval = 0.00000 | val =  0.494
#         ($X_0$ -1): pval = 0.00000 | val =  0.303
#         ($X_6$ -2): pval = 0.02000 | val =  0.067
#
#     Variable $X_5$ has 2 link(s):
#         ($X_6$ -1): pval = 0.01600 | val =  0.070
#         ($X_1$ -2): pval = 0.03700 | val =  0.061
#
#     Variable $X_6$ has 0 link(s):
# PCMCI executional time: 0:23:52.082169

# %% [markdown]
# As you can see, the PCMCI creates spurious links due to the presence of the variable $X_6$. Moreover, the executional time is significantly higher with respect to the FPCMCI one.
#
# FPCMCI executional time ~ 6min 30sec<br>
# PCMCI executional time ~ 23min 52sec<br>
# <br>
# The comparison confirms that the FPCMCI results <strong>faster</strong> and <strong>more accurate</strong> than the PCMCI.
